# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from tensorflow.keras import layers, models
import numpy as np



# -----------------------------
# 1) 데이터 준비
# -----------------------------


df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/winequality-white.csv", sep=";").dropna()
df  # print(df) 와 동일
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
# 가능하면 프로그램을 step-by-step으로 수행하도록 나눠서 작성요망

# %%
#레이블 불균형 확인

df['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %%
# 레이블 갯수 확인 (그래프)

import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data = df, x="quality")
plt.xlabel("Quality")        # 그래프 x 축 이름
plt.ylabel("Count")        # 그래프 y 축 이름
plt.title("Quality")
# Out:
# Text(0.5, 1.0, 'Quality')

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.columns  # 컬럼명 확인
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
X=df.drop('quality',axis=1)
y=df['quality']

# %%
#스케일러

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)

Y = pd.get_dummies(y).values

# %%
# 훈련과 테스트 데이터 분리


X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, stratify=Y, random_state=42

)

# %%
df # 모든 컬럼 값이 숫자로 변경되었는지 확인
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
X # 분리 후 확인
# Out:
# array([[ 1.72096961e-01, -8.17699008e-02,  2.13280202e-01, ...,
#         -1.24692128e+00, -3.49184257e-01, -1.39315246e+00],
#        [-6.57501128e-01,  2.15895632e-01,  4.80011213e-02, ...,
#          7.40028640e-01,  1.34184656e-03, -8.24275678e-01],
#        [ 1.47575110e+00,  1.74519434e-02,  5.43838363e-01, ...,
#          4.75101984e-01, -4.36815783e-01, -3.36667007e-01],
#        ...,
#        [-4.20473102e-01, -3.79435433e-01, -1.19159198e+00, ...,
#         -1.31315295e+00, -2.61552731e-01, -9.05543789e-01],
#        [-1.60561323e+00,  1.16673788e-01, -2.82557040e-01, ...,
#          1.00495530e+00, -9.62604939e-01,  1.85757201e+00],
#        [-1.01304317e+00, -6.77100966e-01,  3.78559282e-01, ...,
#          4.75101984e-01, -1.48839409e+00,  1.04489089e+00]])

# %%
Y # 분리 후 확인
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ...,  True, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape  # 각 데이터의 shape 확인 (전체데이터 수, 컬럼숫자)
# Out:
# ((3918, 11), (980, 11), (3918, 7), (980, 7))

# %%
# -----------------------------
# 2) 모델 구성
# -----------------------------
model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X.shape[1],)),
    layers.Dropout(0.3),
    layers.Dense(32, activation="relu"),
    layers.Dense(Y.shape[1], activation="softmax")   # 클래스 수 맞춤
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",   # one-hot이면 categorical_crossentropy
    metrics=["accuracy"]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# -----------------------------
# 3) 모델 학습
# -----------------------------
history = model.fit(
    X_train, Y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3986 - loss: 1.5674 - val_accuracy: 0.5293 - val_loss: 1.2016
# Epoch 2/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5205 - loss: 1.1637 - val_accuracy: 0.5166 - val_loss: 1.1526
# Epoch 3/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5484 - loss: 1.1209 - val_accuracy: 0.5459 - val_loss: 1.1192
# Epoch 4/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5476 - loss: 1.1213 - val_accuracy: 0.5217 - val_loss: 1.1095
# Epoch 5/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5518 - loss: 1.0842 - val_accuracy: 0.5370 - val_loss: 1.0961
# Epoch 6/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5484 - loss: 1.0895 - val_accuracy: 0.5344 - val_loss: 1.0955
# Epoch 7/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5473 - loss: 1.0608 - val_accuracy: 0.5370 - val_loss: 1.0944
# Epoch 8/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5642 - loss: 1.0483 - val_accuracy: 0.5434 - val_loss: 1.0847
# Epoch 9/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5782 - loss: 1.0289 - val_accuracy: 0.5446 - val_loss: 1.0780
# Epoch 10/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5730 - loss: 1.0329 - val_accuracy: 0.5370 - val_loss: 1.0872
# Epoch 11/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5795 - loss: 1.0293 - val_accuracy: 0.5383 - val_loss: 1.0768
# Epoch 12/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5867 - loss: 1.0015 - val_accuracy: 0.5485 - val_loss: 1.0746
# Epoch 13/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5696 - loss: 1.0327 - val_accuracy: 0.5459 - val_loss: 1.0748
# Epoch 14/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5690 - loss: 1.0298 - val_accuracy: 0.5344 - val_loss: 1.0777
# Epoch 15/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5778 - loss: 1.0022 - val_accuracy: 0.5421 - val_loss: 1.0756
# Epoch 16/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5798 - loss: 1.0220 - val_accuracy: 0.5357 - val_loss: 1.0724
# Epoch 17/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5624 - loss: 1.0169 - val_accuracy: 0.5421 - val_loss: 1.0710
# Epoch 18/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5974 - loss: 0.9908 - val_accuracy: 0.5383 - val_loss: 1.0747
# Epoch 19/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5560 - loss: 1.0288 - val_accuracy: 0.5306 - val_loss: 1.0818
# Epoch 20/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5732 - loss: 1.0073 - val_accuracy: 0.5446 - val_loss: 1.0699
# Epoch 21/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5669 - loss: 1.0137 - val_accuracy: 0.5293 - val_loss: 1.0720
# Epoch 22/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5829 - loss: 0.9731 - val_accuracy: 0.5370 - val_loss: 1.0669
# Epoch 23/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5811 - loss: 0.9880 - val_accuracy: 0.5472 - val_loss: 1.0676
# Epoch 24/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5843 - loss: 0.9933 - val_accuracy: 0.5293 - val_loss: 1.0763
# Epoch 25/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5782 - loss: 0.9925 - val_accuracy: 0.5306 - val_loss: 1.0662
# Epoch 26/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6010 - loss: 0.9332 - val_accuracy: 0.5332 - val_loss: 1.0773
# Epoch 27/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5723 - loss: 0.9987 - val_accuracy: 0.5306 - val_loss: 1.0777
# Epoch 28/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5850 - loss: 0.9708 - val_accuracy: 0.5268 - val_loss: 1.0784
# Epoch 29/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5803 - loss: 0.9564 - val_accuracy: 0.5408 - val_loss: 1.0663
# Epoch 30/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5931 - loss: 0.9598 - val_accuracy: 0.5370 - val_loss: 1.0617
# Epoch 31/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5922 - loss: 0.9595 - val_accuracy: 0.5357 - val_loss: 1.0580
# Epoch 32/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5974 - loss: 0.9535 - val_accuracy: 0.5166 - val_loss: 1.0717
# Epoch 33/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5752 - loss: 0.9884 - val_accuracy: 0.5408 - val_loss: 1.0641
# Epoch 34/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6090 - loss: 0.9429 - val_accuracy: 0.5293 - val_loss: 1.0704
# Epoch 35/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5935 - loss: 0.9598 - val_accuracy: 0.5306 - val_loss: 1.0661
# Epoch 36/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6020 - loss: 0.9613 - val_accuracy: 0.5421 - val_loss: 1.0692
# Epoch 37/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5878 - loss: 0.9686 - val_accuracy: 0.5446 - val_loss: 1.0604
# Epoch 38/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6030 - loss: 0.9544 - val_accuracy: 0.5293 - val_loss: 1.0613
# Epoch 39/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5950 - loss: 0.9411 - val_accuracy: 0.5306 - val_loss: 1.0697
# Epoch 40/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5887 - loss: 0.9422 - val_accuracy: 0.5357 - val_loss: 1.0628
# Epoch 41/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5859 - loss: 0.9278 - val_accuracy: 0.5510 - val_loss: 1.0627
# Epoch 42/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6119 - loss: 0.9603 - val_accuracy: 0.5217 - val_loss: 1.0712
# Epoch 43/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6099 - loss: 0.9392 - val_accuracy: 0.5255 - val_loss: 1.0773
# Epoch 44/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5989 - loss: 0.9501 - val_accuracy: 0.5332 - val_loss: 1.0654
# Epoch 45/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6142 - loss: 0.9220 - val_accuracy: 0.5370 - val_loss: 1.0687
# Epoch 46/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5939 - loss: 0.9441 - val_accuracy: 0.5395 - val_loss: 1.0679
# Epoch 47/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6068 - loss: 0.9312 - val_accuracy: 0.5383 - val_loss: 1.0579
# Epoch 48/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5943 - loss: 0.9349 - val_accuracy: 0.5383 - val_loss: 1.0601
# Epoch 49/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5996 - loss: 0.9373 - val_accuracy: 0.5332 - val_loss: 1.0655
# Epoch 50/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6120 - loss: 0.9101 - val_accuracy: 0.5319 - val_loss: 1.0679

# %%
# -----------------------------
# 4) 예측결과 생성
# -----------------------------

y_pred = model.predict(X_test)

y_test_class = np.argmax(Y_test, axis=1)
y_pred_class = np.argmax(y_pred, axis=1)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# 학습 곡선

loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.55      0.18      0.27        33
#            2       0.59      0.63      0.61       291
#            3       0.55      0.67      0.60       440
#            4       0.48      0.35      0.40       176
#            5       0.33      0.03      0.05        35
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.56       980
#    macro avg       0.36      0.26      0.28       980
# weighted avg       0.54      0.56      0.54       980
#
# [[  0   0   1   3   0   0   0]
#  [  0   6  15  11   1   0   0]
#  [  0   3 183  99   5   1   0]
#  [  0   2 100 293  45   0   0]
#  [  0   0   8 106  61   1   0]
#  [  0   0   1  18  15   1   0]
#  [  0   0   0   0   1   0   0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
